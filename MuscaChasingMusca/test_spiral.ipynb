# %%
import numpy as np
import numpy as np
import plotly.graph_objects as go

# %%
# Spiral parameters
num_points = 500
theta = np.linspace(0, 8 * np.pi, num_points)
z = np.linspace(0, 5, num_points)
r = 0.1 * theta  # radius grows with angle

# First spiral (spiral A)
x1 = r * np.cos(theta)
x1 = x1[delay_steps:]
y1 = r * np.sin(theta)
y1 = y1[delay_steps:]
z1 = z
z1 = z1[delay_steps:]

# Spiral B (50 ms delay simulated by skipping initial segment)
delay_ms = 50
time_per_step_ms = 1  # simulate each step as 1ms
delay_steps = int(delay_ms / time_per_step_ms)

# Spiral B with Z-offset
z_offset = 1
x2 = r[delay_steps:] * np.cos(theta[delay_steps:])
y2 = r[delay_steps:] * np.sin(theta[delay_steps:])
z2 = z[delay_steps:] + z_offset

# %%
# Create traces
spiral_a = go.Scatter3d(
    x=x1, y=y1, z=z1,
    mode='lines',
    line=dict(color='blue', width=4),
    name='Spiral A'
)

spiral_b = go.Scatter3d(
    x=x2, y=y2, z=z2,
    mode='lines',
    line=dict(color='red', width=4),
    name='Spiral B (Delayed)'
)

# Layout
layout = go.Layout(
    title="Two 3D Spirals with Z Offset and 50ms Time Delay",
    scene=dict(
        xaxis=dict(title='X'),
        yaxis=dict(title='Y'),
        zaxis=dict(title='Z')
    )
)

# Plot
fig = go.Figure(data=[spiral_a, spiral_b], layout=layout)
fig.show()
# Out:
# <div>                            <div id="8ecae699-f372-4ff8-9038-f4b616629dae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ecae699-f372-4ff8-9038-f4b616629dae")) {                    Plotly.newPlot(                        "8ecae699-f372-4ff8-9038-f4b616629dae",                        [{"line":{"color":"blue","width":4},"mode":"lines","name":"Spiral A","x":[-0.20447856541229514,-0.21585208885431384,-0.22695307494618705,-0.23773156558792355,-0.2481377786630065,-0.25812229122347324,-0.26763622324777675,-0.2766314213572362,-0.28506064187360175,-0.29287773259892863,-0.30003781269958396,-0.30649745007880386,-0.31221483562678304,-0.31714995374379695,-0.32126474854031944,-0.32452328512849604,-0.32689190543161967,-0.328339377952425,-0.3288370409570121,-0.3283589385490014,-0.32688194912805746,-0.32438590574814113,-0.320853707913708,-0.3162714243764966,-0.3106283865214724,-0.3039172719578455,-0.29613417795977576,-0.2872786844313425,-0.2773539061014981,-0.2663665336869499,-0.2543268637941407,-0.24124881736561424,-0.22714994651096365,-0.21205142959817247,-0.19597805451733852,-0.17895819006545366,-0.16102374543793488,-0.14221011784991178,-0.12255612834769805,-0.10210394590835341,-0.08089899996262606,-0.05898988151374187,-0.036428233061398876,-0.013268627576752234,0.010431563189892355,0.03461231075172095,0.05921108192692161,0.08416300049396452,0.10940101804291551,0.1348560935734466,0.16045738135984122,0.18613242657414547,0.2118073681309004,0.23740714819059025,0.2628557277342157,0.2880763075983157,0.3129915543383518,0.3375238302687952,0.3615954270104778,0.38512880185996284,0.4080468162818103,0.4302729758127862,0.45173167065730935,0.47234841624576357,0.4920500930218223,0.510765184721584,0.5284240144062038,0.5449589775107807,0.5603047711755612,0.5743986191310569,0.5871804914164084,0.5985933182202962,0.6085831971458369,0.6170995932152226,0.6240955309463188,0.6295277778519788,0.6333570187334577,0.6355480201619174,0.6360697845665947,0.634895693374665,0.6320036386761202,0.6273761429170235,0.6210004661562104,0.6128687004538033,0.6029778509947123,0.5913299035864926,0.5779318782084434,0.5627958683275527,0.5459390657367017,0.527383770711352,0.5071573873226063,0.48529240378698185,0.461826357776283,0.43680178665457486,0.410266162653208,0.38227181303909996,0.35287582537586243,0.3221399380217262,0.2901304160525123,0.2569179128418789,0.22257731757474405,0.1871875890128754,0.15083157587415003,0.11359582422871076,0.07557037235605717,0.03684853354696639,-0.002473332627215933,-0.04229606001790098,-0.08251792597915879,-0.12303491119355178,-0.1637409685802694,-0.20452830059063629,-0.24528764416658563,-0.28590856261003306,-0.3262797435855099,-0.36628930245481106,-0.40582509012104184,-0.44477500454020374,-0.4830273050415969,-0.5204709285837679,-0.5569958070605481,-0.5924931847620938,-0.6268559350886104,-0.6599788756098363,-0.6917590805612178,-0.7220961898682529,-0.7508927137935613,-0.7780543323069156,-0.8034901882868085,-0.8271131736730023,-0.8488402077030128,-0.8685925063814887,-0.8862958423500384,-0.9018807943461054,-0.9152829854629756,-0.9264433094489143,-0.9353081443116358,-0.9418295525248126,-0.9459654671659996,-0.947679863350159,-0.9469429143597912,-0.9437311319114352,-0.938027490038906,-0.9298215321159637,-0.9191094605850649,-0.9058942090043164,-0.8901854960716065,-0.8719998613330027,-0.8513606823317804,-0.8282981730047033,-0.8028493631833166,-0.7750580591098767,-0.7449747849300203,-0.7126567051771597,-0.6781675283167976,-0.6415773914723418,-0.6029627265073207,-0.5624061076921596,-0.5199960812365505,-0.47582697702098004,-0.4299987029128173,-0.38261652210349806,-0.33379081395362964,-0.2836368188819953,-0.23227436788250616,-0.17982759729980877,-0.12642464953956367,-0.0721973604330112,-0.017280934017368202,0.038186394466 ...

# %%
# export the two traces as chasee (red, x1,y1,z1) and chaser (blue, x2,y2,z2)

# %%
import pandas as pd

columns = ['chasee_com_x', 'chasee_com_y', 'chasee_com_z',
           'chaser_com_x', 'chaser_com_y', 'chaser_com_z' ]
# Prepare data as list of rows
data = [[xa, ya, za, xb, yb, zb] for xa, ya, za, xb, yb, zb in zip(x1, y1, z1, x2, y2, z2)]


df = pd.DataFrame(data, columns = columns)

# %%
df.head()
# Out:
#    chasee_com_x  chasee_com_y  chasee_com_z  chaser_com_x  chaser_com_y  \
# 0     -0.204479      0.146995      0.501002     -0.204479      0.146995
# 1     -0.215852      0.139244      0.511022     -0.215852      0.139244
# 2     -0.226953      0.130714      0.521042     -0.226953      0.130714
# 3     -0.237732      0.121413      0.531062     -0.237732      0.121413
# 4     -0.248138      0.111353      0.541082     -0.248138      0.111353
#
#    chaser_com_z
# 0      1.501002
# 1      1.511022
# 2      1.521042
# 3      1.531062
# 4      1.541082

# %%
df.to_csv('../dataFolders/MuscaChasingMusca/Outputs/test_spiral_COM.csv')
